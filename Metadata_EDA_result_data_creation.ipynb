# %%
import pandas as pd
import os

# %%
pwd
# Out:
# '/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/Code'

# %%
path = '/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/kaggle_Data/'

# %%
for each in os.listdir(path):
    print(each)
# Out:
# TeamMemberships.csv
# DatasetTasks.csv
# Competitions.csv
# .DS_Store
# Teams.csv
# Datasets.csv
# ForumMessages.csv
# Users.csv
# ForumTopics.csv
# UserAchievements.csv
# Forums.csv
# DatasetTags.csv
# Tags.csv
# Submissions.csv
# Organizations.csv
# DatasetVersions.csv
# DatasetVotes.csv
# CompetitionTags.csv

# %%
df_competition = pd.read_csv("/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/kaggle_Data/Competitions.csv")

# %%
df_competition.shape
# Out:
# (5568, 42)

# %%
df_competition.head()
# Out:
#      Id            Slug                                  Title  \
# 0  2408  Eurovision2010             Forecast Eurovision Voting
# 1  2435  hivprogression                Predict HIV Progression
# 2  2438    worldcup2010    World Cup 2010 - Take on the Quants
# 3  2439     informs2010       INFORMS Data Mining Contest 2010
# 4  2442    worldcupconf  World Cup 2010 - Confidence Challenge
#
#                                             Subtitle HostSegmentTitle  \
# 0  This competition requires contestants to forec...         Featured
# 1  This contest requires competitors to predict t...         Featured
# 2  Quants at Goldman Sachs and JP Morgan have mod...         Featured
# 3  The goal of this contest is to predict short t...         Featured
# 4  The Confidence Challenge requires competitors ...         Featured
#
#    ForumId  OrganizationId  CompetitionTypeId          EnabledDate  \
# 0      2.0             NaN                  1  04/07/2010 07:57:43
# ...

# %%
comp_ids = [22990, 10418, 23823, 27177, 27290, 11433, 14502, 34547, 29653, 20604]
hubmap_comp = df_competition[df_competition.Id.isin(comp_ids)]

# %%
comps = ['D012554 - 2021',
 'XRay Lung Segmentation',
 'BMI707-EPI290 Assignment 2 Q5',
 'ECE4250 Project - Spring 2019',
 'Human Protein Atlas - Single Cell Classification',
 'HuBMAP + HPA - Hacking the Human Body',
 'HuBMAP - Hacking the Kidney',
 'RSNA-MICCAI Brain Tumor Radiogenomic Classification',
 'OSIC Pulmonary Fibrosis Progression',
 'Human Protein Atlas Image Classification']

# %%
comp_names = dict(zip(hubmap_comp.Id, hubmap_comp.Title))
comp_names
# Out:
# {10418: 'Human Protein Atlas Image Classification',
#  11433: 'XRay Lung Segmentation',
#  14502: 'ECE4250 Project : Spring 2019',
#  20604: 'OSIC Pulmonary Fibrosis Progression',
#  22990: 'HuBMAP - Hacking the Kidney',
#  23823: 'Human Protein Atlas - Single Cell Classification',
#  27177: 'D012554 - 2021',
#  27290: 'BMI707/EPI290 Assignment 2 Q5',
#  29653: 'RSNA-MICCAI Brain Tumor Radiogenomic Classification',
#  34547: 'HuBMAP + HPA - Hacking the Human Body'}

# %%
hubmap_comp.shape
# Out:
# (10, 42)

# %%
hubmap_comp.to_csv("2_comp_filtered.csv",index=False)

# %%
hubmap_comp.columns
# Out:
# Index(['Id', 'Slug', 'Title', 'Subtitle', 'HostSegmentTitle', 'ForumId',
#        'OrganizationId', 'CompetitionTypeId', 'EnabledDate', 'DeadlineDate',
#        'ProhibitNewEntrantsDeadlineDate', 'TeamMergerDeadlineDate',
#        'TeamModelDeadlineDate', 'ModelSubmissionDeadlineDate',
#        'FinalLeaderboardHasBeenVerified', 'HasKernels',
#        'OnlyAllowKernelSubmissions', 'HasLeaderboard', 'LeaderboardPercentage',
#        'LeaderboardDisplayFormat', 'EvaluationAlgorithmAbbreviation',
#        'EvaluationAlgorithmName', 'EvaluationAlgorithmDescription',
#        'EvaluationAlgorithmIsMax', 'MaxDailySubmissions',
#        'NumScoredSubmissions', 'MaxTeamSize', 'BanTeamMergers',
#        'EnableTeamModels', 'RewardType', 'RewardQuantity', 'NumPrizes',
#        'UserRankMultiplier', 'CanQualifyTiers', 'TotalTeams',
#        'TotalCompetitors', 'TotalSubmissions', 'ValidationSetName',
#        'ValidationSetValue', 'EnableSubmissionModelHashes',
# ...

# %%
df_submission = pd.read_csv("/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/kaggle_Data/Submissions.csv")
df_teams = pd.read_csv("/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/kaggle_Data/Teams.csv")
df_teammembership = pd.read_csv("/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/kaggle_Data/TeamMemberships.csv")
df_user = pd.read_csv("/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/kaggle_Data/Users.csv")

# %%
df_teams.head()
# Out:
#     Id  CompetitionId  TeamLeaderId      TeamName  ScoreFirstSubmittedDate  \
# 0  496           2435         647.0         team1                      NaN
# 1  497           2435         619.0          jonp                      NaN
# 2  499           2435         663.0         Bwaas                      NaN
# 3  500           2435         673.0    Thylacoleo                      NaN
# 4  501           2435         435.0  pjonesdotcda                      NaN
#
#   LastSubmissionDate  PublicLeaderboardSubmissionId  \
# 0         05/04/2010                         2192.0
# 1         04/30/2010                         2182.0
# 2         05/01/2010                         2184.0
# 3         07/10/2010                         2187.0
# 4         05/05/2010                         2194.0
#
#    PrivateLeaderboardSubmissionId  IsBenchmark  Medal MedalAwardDate  \
# 0                          2192.0        False    NaN     09/06/2018
# ...

# %%
df_teams_filtered = df_teams[df_teams.CompetitionId.isin(comp_ids)]
df_teams_filtered.shape
# Out:
# (94170, 14)

# %%
df_teams_filtered.CompetitionId.nunique()
# Out:
# 10

# %%
df_teams_filtered.columns
# Out:
# Index(['Id', 'CompetitionId', 'TeamLeaderId', 'TeamName',
#        'ScoreFirstSubmittedDate', 'LastSubmissionDate',
#        'PublicLeaderboardSubmissionId', 'PrivateLeaderboardSubmissionId',
#        'IsBenchmark', 'Medal', 'MedalAwardDate', 'PublicLeaderboardRank',
#        'PrivateLeaderboardRank', 'WriteUpForumTopicId'],
#       dtype='object')

# %%
df_teams_filtered = df_teams_filtered[['Id', 'CompetitionId', 'TeamLeaderId','IsBenchmark','PublicLeaderboardRank']]

# %%
df_teams_filtered['PublicLeaderboardRank'].value_counts()
# Out:
# 1.0       10
# 11.0       9
# 7.0        9
# 2.0        9
# 10.0       9
#           ..
# 2121.0     1
# 2139.0     1
# 2150.0     1
# 2098.0     1
# 2113.0     1
# Name: PublicLeaderboardRank, Length: 2160, dtype: int64

# %%
df_teams_filtered.rename(columns={'TeamId':'Team_Id'},inplace=True)

# %%
df_teams_top5 = df_teams_filtered[df_teams_filtered['PublicLeaderboardRank']<=10]
df_teams_top5.shape
# Out:
# (91, 5)

# %%
set(comp_ids) - set(df_teams_top5.CompetitionId.unique())
# Out:
# set()

# %%
set(comp_ids) - set(df_teams_top5.CompetitionId.unique())
# Out:
# {9318, 9511, 13050, 22995}

# %%
df_teams_filtered.rename(columns={'TeamId':'Team_Id'},inplace=True)

# %%
df_teams_top5.rename(columns={'Id':'Team_Id'},inplace=True)
# Out:
# /Users/prataprc94/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_teams_filtered.shape
# Out:
# (94170, 5)

# %%
df_teams_filtered.Team_Id.nunique()
# Out:
# 94170

# %%
df_teams_filtered.head()
# Out:
#          Team_Id  CompetitionId  TeamLeaderId  IsBenchmark  \
# 1211404  1984347          10418     1537731.0        False
# 1217059  1993139          10418           NaN         True
# 1329792  2160465          10418      115173.0        False
# 1330228  2161084          10418     1952004.0        False
# 1337036  2170611          10418     2141686.0        False
#
#          PublicLeaderboardRank
# 1211404                    NaN
# 1217059                    NaN
# 1329792                    NaN
# 1330228                    NaN
# 1337036                    NaN

# %%
df_teams_top5.head()
# Out:
#          Team_Id  CompetitionId  TeamLeaderId  IsBenchmark  \
# 1347708  2185832          10418      772323.0        False
# 1349660  2188629          10418      478989.0        False
# 1371951  2220101          10418     1089347.0        False
# 1383464  2238150          10418      708283.0        False
# 1389713  2247423          10418      710784.0        False
#
#          PublicLeaderboardRank
# 1347708                    8.0
# 1349660                    9.0
# 1371951                    2.0
# 1383464                    1.0
# 1389713                   10.0

# %%
#top_teams = df_teams_top5.Team_Id.unique()
top_teams = df_teams_filtered.Team_Id.unique()

# %%
df_teammembership.head()
# Out:
#        Id  TeamId  UserId RequestDate
# 0  497916  469024  200660  02/06/2017
# 1  524121  494689  777876  02/20/2017
# 2  542461  512626  937118  03/01/2017
# 3  545506  515650  933895  03/03/2017
# 4  550260  520368  915112  03/06/2017

# %%
df_teammembers_filtered = df_teammembership[df_teammembership.TeamId.isin(top_teams)]
df_teammembers_filtered.shape
# Out:
# (98409, 4)

# %%
df_teammembers_filtered = df_teammembers_filtered[['TeamId','UserId']]

# %%
df_teammembers_filtered.rename(columns={'TeamId':'Team_Id'},inplace=True)

# %%
df_teammembers_filtered.UserId.value_counts()
# Out:
# 1348567    10
# 2360956     9
# 207760      9
# 1684129     8
# 1120704     8
#            ..
# 1131967     1
# 3714498     1
# 1877443     1
# 564676      1
# 2388566     1
# Name: UserId, Length: 75132, dtype: int64

# %%
df_teammembers_filtered.Team_Id.nunique(),df_teammembers_filtered.UserId.nunique()
# Out:
# (94150, 75132)

# %%
df_teams_filtered.head()
# Out:
#          Team_Id  CompetitionId  TeamLeaderId  IsBenchmark  \
# 1211404  1984347          10418     1537731.0        False
# 1217059  1993139          10418           NaN         True
# 1329792  2160465          10418      115173.0        False
# 1330228  2161084          10418     1952004.0        False
# 1337036  2170611          10418     2141686.0        False
#
#          PublicLeaderboardRank
# 1211404                    NaN
# 1217059                    NaN
# 1329792                    NaN
# 1330228                    NaN
# 1337036                    NaN

# %%
df_teammembers_filtered.head()
# Out:
#          Team_Id   UserId
# 1718837  1984347  1537731
# 1718838  2160465   115173
# 1718839  2161084  1952004
# 1718840  2170611  2141686
# 1718841  2173363  2152586

# %%
team_df = pd.merge(df_teammembers_filtered,df_teams_filtered[['Team_Id','CompetitionId','TeamLeaderId','PublicLeaderboardRank']],on = 'Team_Id',how='left').reset_index()

# %%
team_df.shape
# Out:
# (98409, 6)

# %%
team_df.head()
# Out:
#    index  Team_Id   UserId  CompetitionId  TeamLeaderId  PublicLeaderboardRank
# 0      0  1984347  1537731          10418     1537731.0                    NaN
# 1      1  2160465   115173          10418      115173.0                    NaN
# 2      2  2161084  1952004          10418     1952004.0                    NaN
# 3      3  2170611  2141686          10418     2141686.0                    NaN
# 4      4  2173363  2152586          10418     2152586.0                    NaN

# %%
team_df.drop('index',axis=1,inplace=True)

# %%
team_df.CompetitionId.nunique()
# Out:
# 10

# %%
top_users = team_df.UserId.unique()
top_users
# Out:
# array([ 1537731,   115173,  1952004, ...,  8494163,  8414901, 11971282])

# %%
len(top_users)
# Out:
# 75132

# %%
df_user.head()
# Out:
#     Id      UserName        DisplayName RegisterDate  PerformanceTier
# 0    1    kaggleteam        Kaggle Team   03/24/2011                5
# 1  368  antgoldbloom  Anthony Goldbloom   01/20/2010                2
# 2  381        iguyon           Isabelle   01/29/2010                2
# 3  383  davidstephan      David Stephan   02/01/2010                0
# 4  384    gabewarren        Gabe Warren   02/02/2010                0

# %%
df_user_filtered = df_user[df_user.Id.isin(top_users)]
df_user_filtered.shape
# Out:
# (73210, 5)

# %%
df_user_filtered.head()
# Out:
#       Id        UserName        DisplayName RegisterDate  PerformanceTier
# 1    368    antgoldbloom  Anthony Goldbloom   01/20/2010                2
# 40   421         dremovd     Dmitry Dryomov   02/28/2010                3
# 204  602        wahalulu      Marck Vaisman   04/28/2010                0
# 208  606         tcash21            tcash21   04/28/2010                1
# 255  661  timderzauberer   tim der zauberer   04/30/2010                0

# %%
all_user_df = df_user.rename(columns={'Id':'UserId'})

# %%
all_user_df.PerformanceTier.unique()
# Out:
# array([5, 2, 0, 1, 3, 4])

# %%
# Create a dictionary to map integer values to their corresponding string names
mapping = {0: 'novice', 1: 'contributor', 2: 'intermediate', 3: 'expert', 4: 'master', 5: 'grandmaster'}

# Apply the mapping to the column using the map function
all_user_df['tier_name'] = all_user_df['PerformanceTier'].map(mapping)

# Print the resulting dataframe

all_user_df.head()
# Out:
#    UserId      UserName        DisplayName RegisterDate  PerformanceTier  \
# 0       1    kaggleteam        Kaggle Team   03/24/2011                5
# 1     368  antgoldbloom  Anthony Goldbloom   01/20/2010                2
# 2     381        iguyon           Isabelle   01/29/2010                2
# 3     383  davidstephan      David Stephan   02/01/2010                0
# 4     384    gabewarren        Gabe Warren   02/02/2010                0
#
#       tier_name
# 0   grandmaster
# 1  intermediate
# 2  intermediate
# 3        novice
# 4        novice

# %%
all_user_df.shape
# Out:
# (12689958, 6)

# %%
all_user_df.to_csv("All_users.csv",index=False)

# %%
df_user_filtered.rename(columns={'Id':'UserId'},inplace=True)
# Out:
# /Users/prataprc94/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_user_filtered.shape
# Out:
# (73210, 5)

# %%
user_df = pd.merge(df_user_filtered,team_df,on = 'UserId',how='left').reset_index()

# %%
df_user.PerformanceTier.unique()
# Out:
# array([5, 2, 0, 1, 3, 4])

# %%
user_df.PerformanceTier.unique()
# Out:
# array([2, 3, 0, 1, 4, 5])

# %%
user_df.shape
# Out:
# (96010, 10)

# %%
user_df.head()
# Out:
#    index  UserId      UserName        DisplayName RegisterDate  \
# 0      0     368  antgoldbloom  Anthony Goldbloom   01/20/2010
# 1      1     368  antgoldbloom  Anthony Goldbloom   01/20/2010
# 2      2     368  antgoldbloom  Anthony Goldbloom   01/20/2010
# 3      3     421       dremovd     Dmitry Dryomov   02/28/2010
# 4      4     602      wahalulu      Marck Vaisman   04/28/2010
#
#    PerformanceTier  Team_Id  CompetitionId  TeamLeaderId  \
# 0                2  3304624          10418         368.0
# 1                2  5556128          20604         368.0
# 2                2  6289988          23823         368.0
# 3                3  5404773          20604         421.0
# 4                0  7093405          29653         602.0
#
#    PublicLeaderboardRank
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                  858.0
# 4                    NaN

# %%
contributor	Human Protein Atlas - Single Cell Classification	3103.0
12	expert	Human Protein Atlas - Single Cell Classification	1065.0
13	grandmaster	Human Protein Atlas - Single Cell Classification	150.0
14	master	Human Protein Atlas - Single Cell Classification	338.0
15	novice

# %%
# Create a dictionary to map integer values to their corresponding string names
mapping = {0: 'novice', 1: 'contributor', 2: 'intermediate', 3: 'expert', 4: 'master', 5: 'grandmaster'}
# Apply the mapping to the column using the map function
user_df['tier_name'] = user_df['PerformanceTier'].map(mapping)

# Print the resulting dataframe

user_df.head()
# Out:
#    index  UserId      UserName        DisplayName RegisterDate  \
# 0      0     368  antgoldbloom  Anthony Goldbloom   01/20/2010
# 1      1     368  antgoldbloom  Anthony Goldbloom   01/20/2010
# 2      2     368  antgoldbloom  Anthony Goldbloom   01/20/2010
# 3      3     421       dremovd     Dmitry Dryomov   02/28/2010
# 4      4     602      wahalulu      Marck Vaisman   04/28/2010
#
#    PerformanceTier  Team_Id  CompetitionId  TeamLeaderId  \
# 0                2  3304624          10418         368.0
# 1                2  5556128          20604         368.0
# 2                2  6289988          23823         368.0
# 3                3  5404773          20604         421.0
# 4                0  7093405          29653         602.0
#
#    PublicLeaderboardRank     tier_name
# 0                    NaN  intermediate
# 1                    NaN  intermediate
# 2                    NaN  intermediate
# 3                  858.0        expert
# 4                    NaN        novice

# %%
user_df.tier_name.unique()
# Out:
# array(['intermediate', 'expert', 'novice', 'contributor', 'master',
#        'grandmaster'], dtype=object)

# %%
hubmap_comp.head()
# Out:
#          Id                                      Slug  \
# 1043  10418  human-protein-atlas-image-classification
# 1183  11433                    xray-lung-segmentation
# 1717  14502              cornell-ece4250-finalproject
# 2808  20604       osic-pulmonary-fibrosis-progression
# 3340  22990                hubmap-kidney-segmentation
#
#                                          Title  \
# 1043  Human Protein Atlas Image Classification
# 1183                    XRay Lung Segmentation
# 1717             ECE4250 Project : Spring 2019
# 2808       OSIC Pulmonary Fibrosis Progression
# 3340               HuBMAP - Hacking the Kidney
#
#                                                Subtitle HostSegmentTitle  \
# 1043  Classify subcellular protein patterns in human...         Featured
# 1183  Сегментация легких на рентгенологических изобр...        Community
# 1717                Automatic segmentation of brain MRI        Community
# ...

# %%
user_df.UserId.nunique()
# Out:
# 73210

# %%
user_df.UserId.value_counts()
# Out:
# 1348567    10
# 2360956     9
# 207760      9
# 1684129     8
# 5569141     8
#            ..
# 2083045     1
# 6180318     1
# 1197535     1
# 5486049     1
# 2388566     1
# Name: UserId, Length: 73210, dtype: int64

# %%
user_df['TeamLeaderId'] = user_df['TeamLeaderId'].astype(int)

# %%
user_df.dtypes
# Out:
# index                      int64
# UserId                     int64
# UserName                  object
# DisplayName               object
# RegisterDate              object
# PerformanceTier            int64
# Team_Id                    int64
# CompetitionId              int64
# TeamLeaderId               int64
# PublicLeaderboardRank    float64
# tier_name                 object
# dtype: object

# %%
user_df['isLeader'] = (user_df['UserId']==user_df['TeamLeaderId'])

# %%
user_df.head()
# Out:
#    index  UserId      UserName        DisplayName RegisterDate  \
# 0      0     368  antgoldbloom  Anthony Goldbloom   01/20/2010
# 1      1     368  antgoldbloom  Anthony Goldbloom   01/20/2010
# 2      2     368  antgoldbloom  Anthony Goldbloom   01/20/2010
# 3      3     421       dremovd     Dmitry Dryomov   02/28/2010
# 4      4     602      wahalulu      Marck Vaisman   04/28/2010
#
#    PerformanceTier  Team_Id  CompetitionId  TeamLeaderId  \
# 0                2  3304624          10418           368
# 1                2  5556128          20604           368
# 2                2  6289988          23823           368
# 3                3  5404773          20604           421
# 4                0  7093405          29653           602
#
#    PublicLeaderboardRank     tier_name  isLeader
# 0                    NaN  intermediate      True
# 1                    NaN  intermediate      True
# 2                    NaN  intermediate      True
# ...

# %%
user_df['UserId'][4] == user_df['TeamLeaderId'][4]
# Out:
# True

# %%
user_df['isLeader'].value_counts()
# Out:
# True     91873
# False     4137
# Name: isLeader, dtype: int64

# %%
user_df.drop('index',axis=1,inplace=True)

# %%
uuu = pd.read_csv('/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/Processed_Data/Intermediate/All_users.csv')
uuu.shape
# Out:
# (12689958, 6)

# %%
user_df.to_csv('/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/Processed_Data/Intermediate/all_users_top10comps_.csv',index=False)

# %%
user_df.groupby(['Team_Id','PerformanceTier'])['UserId'].count()
# Out:
# Team_Id   PerformanceTier
# 1984347   1                  1
# 2160465   5                  1
# 2161084   1                  1
# 2170611   0                  1
# 2173363   0                  1
#                             ..
# 10043585  0                  1
# 10043614  0                  1
# 10044074  0                  1
# 10045200  0                  1
# 10045570  0                  1
# Name: UserId, Length: 93138, dtype: int64

# %%
user_df.shape
# Out:
# (96010, 11)

# %%
df_isleader= pd.DataFrame(user_df.groupby(['PublicLeaderboardRank','PerformanceTier','tier_name'])['TeamLeaderId'].count()).reset_index()
df_isleader
# Out:
#       PublicLeaderboardRank  PerformanceTier     tier_name  TeamLeaderId
# 0                       1.0                0        novice             2
# 1                       1.0                1   contributor             1
# 2                       1.0                2  intermediate             2
# 3                       1.0                4        master             8
# 4                       2.0                0        novice             4
# ...                     ...              ...           ...           ...
# 5519                 2156.0                2  intermediate             1
# 5520                 2157.0                1   contributor             1
# 5521                 2158.0                1   contributor             1
# 5522                 2159.0                0        novice             1
# 5523                 2160.0                0        novice             1
#
# [5524 rows x 4 columns]

# %%
df_isleader.rename(columns={'TeamLeaderId':'Count'},inplace=True)
df_isleader
# Out:
#       PublicLeaderboardRank  PerformanceTier     tier_name  Count
# 0                       1.0                0        novice      2
# 1                       1.0                1   contributor      1
# 2                       1.0                2  intermediate      2
# 3                       1.0                4        master      8
# 4                       2.0                0        novice      4
# ...                     ...              ...           ...    ...
# 5519                 2156.0                2  intermediate      1
# 5520                 2157.0                1   contributor      1
# 5521                 2158.0                1   contributor      1
# 5522                 2159.0                0        novice      1
# 5523                 2160.0                0        novice      1
#
# [5524 rows x 4 columns]

# %%
df_isleader.to_csv("/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/Processed_Data/Intermediate/all_leader_rank_tier.csv",index=False)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=df_isleader, x='PublicLeaderboardRank', y='Count',hue="tier_name")
plt.title('Team Leader Tier Distribution for Top 10 Ranked Teams For All Competitions', fontsize = 15)
plt.xlabel('Public Leaderboard Rank', fontsize =15)
plt.ylabel('Team Leader Count', fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
df_submission.shape
# Out:
# (12042231, 11)

# %%
df_submission.head()
# Out:
#        Id  SubmittedUserId  TeamId  SourceKernelVersionId SubmissionDate  \
# 0  184060           1004.0   23047                    NaN     09/11/2012
# 1  184107           1004.0   23047                    NaN     09/11/2012
# 2  182492           1004.0   23047                    NaN     09/07/2012
# 3  182637           1004.0   23047                    NaN     09/07/2012
# 4  186098           5462.0   23090                    NaN     09/17/2012
#
#   ScoreDate  IsAfterDeadline  PublicScoreLeaderboardDisplay  \
# 0       NaN            False                        0.19334
# 1       NaN            False                        0.20183
# 2       NaN            False                        0.19653
# 3       NaN            False                        0.19568
# 4       NaN            False                        0.16108
#
#    PublicScoreFullPrecision  PrivateScoreLeaderboardDisplay  \
# 0                  0.193348                         0.19185
# ...

# %%
df_teams_filtered.head()
# Out:
#          Team_Id  CompetitionId  TeamLeaderId  IsBenchmark  \
# 1211404  1984347          10418     1537731.0        False
# 1217059  1993139          10418           NaN         True
# 1329792  2160465          10418      115173.0        False
# 1330228  2161084          10418     1952004.0        False
# 1337036  2170611          10418     2141686.0        False
#
#          PublicLeaderboardRank
# 1211404                    NaN
# 1217059                    NaN
# 1329792                    NaN
# 1330228                    NaN
# 1337036                    NaN

# %%
df_teams_filtered.shape
# Out:
# (94170, 5)

# %%
all_teams = df_teams_filtered.Team_Id.unique()

# %%
len(all_teams)
# Out:
# 94170

# %%
df_sub_filtered = df_submission[df_submission.TeamId.isin(all_teams)]

# %%
df_sub_filtered.shape
# Out:
# (258837, 11)

# %%
df_sub_filtered.head()
# Out:
#               Id  SubmittedUserId  Team_Id  SourceKernelVersionId  \
# 4139622  8705562         906325.0  2184008              6466538.0
# 4139623  8701003         906325.0  2184008              6461939.0
# 4139624  8785774         906325.0  2184008              6687978.0
# 4139739  8827329         906325.0  2184008              6780709.0
# 4139740  8837430         906325.0  2184008              6816029.0
#
#         SubmissionDate   ScoreDate  IsAfterDeadline  \
# 4139622     10/14/2018  12/05/2018            False
# 4139623     10/14/2018  12/05/2018            False
# 4139624     10/22/2018  12/05/2018            False
# 4139739     10/26/2018  12/05/2018            False
# 4139740     10/27/2018  12/05/2018            False
#
#          PublicScoreLeaderboardDisplay  PublicScoreFullPrecision  \
# 4139622                        0.13220                  0.132200
# 4139623                        0.26235                  0.262355
# ...

# %%
df_sub_filtered.rename(columns={'TeamId':'Team_Id'},inplace=True)
# Out:
# /Users/prataprc94/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_teams_filtered.rename(columns={'Id':'Team_Id'},inplace=True)

# %%
df_sub_comp = pd.merge(df_sub_filtered,df_teams_filtered[['Team_Id','CompetitionId']],on='Team_Id',how='left').reset_index()

# %%
df_sub_comp.shape
# Out:
# (258837, 13)

# %%
df_sub_comp.to_csv("submission_10competitions.csv",index=False)

# %%
tot_sub = pd.DataFrame(df_sub_comp.groupby('CompetitionId')['SubmittedUserId'].count()).reset_index()

# %%
tot_sub.rename(columns={'SubmittedUserId':'Submission_Count'},inplace=True)

# %%
tot_sub
# Out:
#    CompetitionId  Submission_Count
# 0          10418             69111
# 1          11433               202
# 2          14502               629
# 3          20604             52860
# 4          22990             37190
# 5          23823             23505
# 6          27177                 9
# 7          27290               125
# 8          29653             29566
# 9          34547             45640

# %%
import matplotlib.pyplot as plt
tot_sub.plot(x='CompetitionId', y='Submission_Count', kind='bar') 
plt.title("Total Submissions for each Competition")
plt.show()

# %%
df_sub_comp.columns
# Out:
# Index(['index', 'Id', 'SubmittedUserId', 'TeamId', 'SourceKernelVersionId',
#        'SubmissionDate', 'ScoreDate', 'IsAfterDeadline',
#        'PublicScoreLeaderboardDisplay', 'PublicScoreFullPrecision',
#        'PrivateScoreLeaderboardDisplay', 'PrivateScoreFullPrecision',
#        'CompetitionId'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
ax.boxplot(df_sub_comp['PublicScoreFullPrecision'])
#ax.set_xticklabels(runtime_kvalues.keys())
#plt.title(f"Box Plots of Run Times for All K-values in {algo_name}")
plt.xlabel("Precision score")
#plt.ylabel("Run Time in seconds")
plt.show()

# %%
df_sub_comp.boxplot(column=['PublicScoreFullPrecision'])
# Out:
# <AxesSubplot:>

# %%
df_sub_comp['PublicScoreFullPrecision'].describe()
# Out:
# count    236501.000000
# mean         -1.055221
# std           3.276701
# min         -76.810493
# 25%           0.032452
# 50%           0.440131
# 75%           0.604651
# max          23.847863
# Name: PublicScoreFullPrecision, dtype: float64

# %%
{9318, 9511, 13050, 22995}

# %%
df_sub_comp.head()
# Out:
#    index       Id  SubmittedUserId   TeamId  SourceKernelVersionId  \
# 0      0  7303361        1209171.0  1627797                    NaN
# 1      1  7169979         974032.0  1575627                    NaN
# 2      2  8705562         906325.0  2184008              6466538.0
# 3      3  8701003         906325.0  2184008              6461939.0
# 4      4  8785774         906325.0  2184008              6687978.0
#
#   SubmissionDate   ScoreDate  IsAfterDeadline  PublicScoreLeaderboardDisplay  \
# 0     04/26/2018  04/26/2018            False                        0.00000
# 1     04/11/2018  04/11/2018            False                        0.08823
# 2     10/14/2018  12/05/2018            False                        0.13220
# 3     10/14/2018  12/05/2018            False                        0.26235
# 4     10/22/2018  12/05/2018            False                        0.34494
#
#    PublicScoreFullPrecision  PrivateScoreLeaderboardDisplay  \
# ...

# %%
df_sub_comp.shape
# Out:
# (258837, 13)

# %%
user_df.head()
# Out:
#    UserId       UserName          DisplayName RegisterDate  PerformanceTier  \
# 0   54836       titericz                 Giba   08/23/2012                4
# 1   71783  sergeifironov       Sergei Fironov   11/30/2012                4
# 2  111220     kevinhwang          Kevin Hwang   06/20/2013                3
# 3  207760  igorkrashenyi       Igor Krashenyi   06/12/2014                3
# 4  269744     liaksiejka  Aliaksei Charnevich   12/09/2014                1
#
#    Team_Id  CompetitionId  TeamLeaderId  PublicLeaderboardRank  isLeader
# 0  6145769          22990        698363                    1.0     False
# 1  2274438          10418        837103                    4.0     False
# 2  2261835          10418        417337                    3.0     False
# 3  8893081          34547       1690820                    3.0     False
# 4  2324816          11433        269744                    1.0      True

# %%
df_sub_comp.groupby(['TeamId','CompetitionId'])['PublicScoreLeaderboardDisplay'].max()
# Out:
# TeamId   CompetitionId
# 1575627  9318             0.08823
# 1627797  9511             0.00000
# 1984347  10418            0.01924
# 1993139  10418            0.58172
# 2173489  10418            0.42375
#                            ...
# 9863844  22990            0.88800
# 9886423  34547            0.29290
# 9905604  34547            0.42536
# 9977643  29653            0.65089
# 9989985  34547                NaN
# Name: PublicScoreLeaderboardDisplay, Length: 10534, dtype: float64

# %%
user_df.groupby(['Team_Id','PerformanceTier'])['UserId'].count()
# Out:
# Team_Id  PerformanceTier
# 2220101  2                  1
# 2238150  4                  1
# 2261835  3                  1
#          4                  5
# 2274438  1                  1
#          2                  2
#          4                  1
# 2324816  1                  1
# 2325512  1                  1
# 2363387  1                  1
# 2413555  0                  1
# 2438866  0                  1
# 2494023  3                  2
# 3151801  0                  1
# 3151830  0                  1
# 3160992  0                  1
# 3165641  0                  1
# 3165872  0                  1
# 5228026  3                  1
# 5232660  2                  1
# 5285027  0                  1
# 5328415  2                  1
# 5335718  3                  1
# 5839750  3                  1
# 6145769  4                  2
# 6211473  4                  1
# 6212560  3                  2
#          4                  2
# 6220611  3                  1
#          4                  3
# ...

# %%
user_df.head()
# Out:
#    UserId       UserName     DisplayName RegisterDate  PerformanceTier  \
# 0   54836       titericz            Giba   08/23/2012                4
# 1   71783  sergeifironov  Sergei Fironov   11/30/2012                4
# 2  111220     kevinhwang     Kevin Hwang   06/20/2013                3
# 3  113660       hengck23        ‎‎‎‎‎‎‎‎   07/11/2013                4
# 4  207760  igorkrashenyi  Igor Krashenyi   06/12/2014                3
#
#    Team_Id  CompetitionId  TeamLeaderId  PublicLeaderboardRank  isLeader
# 0  6145769          22990        698363                    1.0     False
# 1  2274438          10418        837103                    4.0     False
# 2  2261835          10418        417337                    3.0     False
# 3  8806840          34547        113660                    7.0      True
# 4  5843694          22990        207760                   10.0      True

# %%
user_df.shape
# Out:
# (157, 10)

# %%
user_df[user_df['CompetitionId']==9511]
# Out:
# Empty DataFrame
# Columns: [UserId, UserName, DisplayName, RegisterDate, PerformanceTier, Team_Id, CompetitionId, TeamLeaderId, PublicLeaderboardRank, isLeader]
# Index: []

# %%
df_sub_comp[df_sub_comp['CompetitionId']==9318]
# Out:
#    index       Id  SubmittedUserId   TeamId  SourceKernelVersionId  \
# 1      1  7169979         974032.0  1575627                    NaN
#
#   SubmissionDate   ScoreDate  IsAfterDeadline  PublicScoreLeaderboardDisplay  \
# 1     04/11/2018  04/11/2018            False                        0.08823
#
#    PublicScoreFullPrecision  PrivateScoreLeaderboardDisplay  \
# 1                  0.088235                            0.08
#
#    PrivateScoreFullPrecision  CompetitionId
# 1                       0.08           9318

# %%
user_df[user_df['Team_Id']==1575627]
# Out:
# Empty DataFrame
# Columns: [UserId, UserName, DisplayName, RegisterDate, PerformanceTier, Team_Id, CompetitionId, TeamLeaderId, PublicLeaderboardRank, isLeader]
# Index: []

# %%
df_teams.head()
# Out:
#     Id  CompetitionId  TeamLeaderId      TeamName  ScoreFirstSubmittedDate  \
# 0  496           2435         647.0         team1                      NaN
# 1  497           2435         619.0          jonp                      NaN
# 2  499           2435         663.0         Bwaas                      NaN
# 3  500           2435         673.0    Thylacoleo                      NaN
# 4  501           2435         435.0  pjonesdotcda                      NaN
#
#   LastSubmissionDate  PublicLeaderboardSubmissionId  \
# 0         05/04/2010                         2192.0
# 1         04/30/2010                         2182.0
# 2         05/01/2010                         2184.0
# 3         07/10/2010                         2187.0
# 4         05/05/2010                         2194.0
#
#    PrivateLeaderboardSubmissionId  IsBenchmark  Medal MedalAwardDate  \
# 0                          2192.0        False    NaN     09/06/2018
# ...

# %%
df_teams[df_teams['Id']==1575627]
# Out:
#              Id  CompetitionId  TeamLeaderId         TeamName  \
# 948394  1575627           9318           NaN  sample_file.csv
#
#         ScoreFirstSubmittedDate LastSubmissionDate  \
# 948394                      NaN         04/11/2018
#
#         PublicLeaderboardSubmissionId  PrivateLeaderboardSubmissionId  \
# 948394                      7169979.0                       7169979.0
#
#         IsBenchmark  Medal MedalAwardDate  PublicLeaderboardRank  \
# 948394         True    NaN            NaN                    NaN
#
#         PrivateLeaderboardRank  WriteUpForumTopicId
# 948394                     NaN                  NaN

# %%
df_teammembership.head()
# Out:
#        Id  TeamId  UserId RequestDate
# 0  497916  469024  200660  02/06/2017
# 1  524121  494689  777876  02/20/2017
# 2  542461  512626  937118  03/01/2017
# 3  545506  515650  933895  03/03/2017
# 4  550260  520368  915112  03/06/2017

# %%
df_user.head()
# Out:
#     Id      UserName        DisplayName RegisterDate  PerformanceTier
# 0    1    kaggleteam        Kaggle Team   03/24/2011                5
# 1  368  antgoldbloom  Anthony Goldbloom   01/20/2010                2
# 2  381        iguyon           Isabelle   01/29/2010                2
# 3  383  davidstephan      David Stephan   02/01/2010                0
# 4  384    gabewarren        Gabe Warren   02/02/2010                0

# %%
df_user.groupby(['Id']).nth(3)
# Out:
# Empty DataFrame
# Columns: [UserName, DisplayName, RegisterDate, PerformanceTier]
# Index: []

# %%
df_teammembership[df_teammembership['TeamId']==1575627]
# Out:
# Empty DataFrame
# Columns: [Id, TeamId, UserId, RequestDate]
# Index: []

# %%
hubmap_comp
# Out:
#          Id                                               Slug  \
# 1043  10418           human-protein-atlas-image-classification
# 1183  11433                             xray-lung-segmentation
# 1717  14502                       cornell-ece4250-finalproject
# 2808  20604                osic-pulmonary-fibrosis-progression
# 3340  22990                         hubmap-kidney-segmentation
# 3483  23823               hpa-single-cell-image-classification
# 4117  27177                                       d012554-2021
# 4134  27290                         2021bmi707-assignment-2-q5
# 4374  29653  rsna-miccai-brain-tumor-radiogenomic-classific...
# 5267  34547                          hubmap-organ-segmentation
#
#                                                   Title  \
# 1043           Human Protein Atlas Image Classification
# 1183                             XRay Lung Segmentation
# 1717                      ECE4250 Project : Spring 2019
# ...

# %%
hubmap_comp['duration'] = pd.to_datetime(hubmap_comp['DeadlineDate']) - pd.to_datetime(hubmap_comp['EnabledDate'])
# Out:
# <ipython-input-95-0c84160679ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hubmap_comp['duration'] = pd.to_datetime(hubmap_comp['DeadlineDate']) - pd.to_datetime(hubmap_comp['EnabledDate'])

# %%
from datetime import datetime as dt

# %%
hubmap_comp['duration'] = hubmap_comp['duration'].dt.days
# Out:
# <ipython-input-97-369c99ab8bdf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hubmap_comp['duration'] = hubmap_comp['duration'].dt.days

# %%
hubmap_comp.columns
# Out:
# Index(['Id', 'Slug', 'Title', 'Subtitle', 'HostSegmentTitle', 'ForumId',
#        'OrganizationId', 'CompetitionTypeId', 'EnabledDate', 'DeadlineDate',
#        'ProhibitNewEntrantsDeadlineDate', 'TeamMergerDeadlineDate',
#        'TeamModelDeadlineDate', 'ModelSubmissionDeadlineDate',
#        'FinalLeaderboardHasBeenVerified', 'HasKernels',
#        'OnlyAllowKernelSubmissions', 'HasLeaderboard', 'LeaderboardPercentage',
#        'LeaderboardDisplayFormat', 'EvaluationAlgorithmAbbreviation',
#        'EvaluationAlgorithmName', 'EvaluationAlgorithmDescription',
#        'EvaluationAlgorithmIsMax', 'MaxDailySubmissions',
#        'NumScoredSubmissions', 'MaxTeamSize', 'BanTeamMergers',
#        'EnableTeamModels', 'RewardType', 'RewardQuantity', 'NumPrizes',
#        'UserRankMultiplier', 'CanQualifyTiers', 'TotalTeams',
#        'TotalCompetitors', 'TotalSubmissions', 'ValidationSetName',
#        'ValidationSetValue', 'EnableSubmissionModelHashes',
# ...

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(14,8)})

ax = sns.barplot(data=hubmap_comp,x='Id',y='duration')
plt.show()

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(14,8)})

ax = sns.barplot(data=hubmap_comp,x='Id',y='RewardQuantity')
plt.show()

# %%
hubmap_comp[['Id','RewardType','RewardQuantity','NumPrizes','TotalCompetitors', 'TotalSubmissions','EvaluationAlgorithmName']]
# Out:
#          Id RewardType  RewardQuantity  NumPrizes  TotalCompetitors  \
# 889    9318        NaN             0.0          0                 0
# 913    9511        NaN             0.0          0                 0
# 1043  10418        USD         37000.0          4              2679
# 1183  11433        NaN             0.0          1                16
# 1440  13050        NaN             NaN          1                 0
# 1717  14502        NaN             NaN          1                53
# 2808  20604        USD         55000.0          3              2530
# 3340  22990        USD         60000.0          3              1625
# 3341  22995        NaN             NaN          1                 0
# 3483  23823        USD         25000.0          3               991
# 4117  27177        NaN             NaN          1                 1
# 4134  27290        NaN             NaN          1                41
# 4374  29653        USD         30000.0          8              1958
# ...

# %%
hubmap_comp.plot.bar(x='Id', y='RewardQuantity', rot=0)
# Out:
# <AxesSubplot:xlabel='Id'>

# %% [markdown]
# ### intermediate result portion

# %%
comp_tag = pd.read_csv("CompetitionTags.csv")

# %%
comp_tag.head()
# Out:
#     Id  CompetitionId  TagId
# 0  126           3486  14102
# 1  336           3526  12116
# 2  335           3526  14101
# 3  334           3526  14104
# 4  362           3706   2606

# %%
comp_ids = [22990, 10418, 23823, 27177, 27290, 11433, 14502, 34547, 29653, 20604]
comp_tag = comp_tag[comp_tag.CompetitionId.isin(comp_ids)]

# %%
comp_tag.shape
# Out:
# (16, 3)

# %%
comp_tag
# Out:
#        Id  CompetitionId  TagId
# 329   429          10418  13302
# 330   428          10418  14102
# 499   694          20604   4202
# 500   693          20604  14102
# 532   748          22990   7100
# 533   743          22990  11111
# 534   742          22990  14102
# 543   772          23823  14102
# 544   773          23823  14202
# 545   774          23823  16636
# 623   847          29653   4202
# 624   845          29653  14102
# 625   846          29653  14201
# 696   981          34547   7100
# 697  1022          34547  13207
# 698   980          34547  14102

# %%
tag_ids = comp_tag.TagId.unique()
tag_ids
# Out:
# array([13302, 14102,  4202,  7100, 11111, 14202, 16636, 14201, 13207])

# %%
tags = pd.read_csv("Tags.csv")
tags.shape
# Out:
# (785, 9)

# %%
tags = tags[tags.Id.isin(tag_ids)]
tags.shape
# Out:
# (9, 9)

# %%
tags.rename(columns={'Id':'TagId'},inplace=True)
# Out:
# /Users/prataprc94/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
comp_tagid_merged = pd.merge(comp_tag,tags,on = 'TagId',how = 'left').reset_index(drop=True)
comp_tagid_merged.shape
# Out:
# (16, 11)

# %%
comp_tagid_merged
# Out:
#       Id  CompetitionId  TagId  ParentTagId                       Name  \
# 0    429          10418  13302      16673.0             classification
# 1    428          10418  14102      14100.0                      image
# 2    694          20604   4202      11111.0                 healthcare
# 3    693          20604  14102      14100.0                      image
# 4    748          22990   7100       7000.0                    biology
# 5    743          22990  11111       4000.0                     health
# 6    742          22990  14102      14100.0                      image
# 7    772          23823  14102      14100.0                      image
# 8    773          23823  14202      13302.0  multiclass classification
# 9    774          23823  16636      16673.0  multilabel classification
# 10   847          29653   4202      11111.0                 healthcare
# 11   845          29653  14102      14100.0                      image
# ...

# %%
comp_tagid_merged.Name.value_counts()
# Out:
# image                        6
# biology                      2
# healthcare                   2
# computer vision              1
# multiclass classification    1
# multilabel classification    1
# classification               1
# health                       1
# binary classification        1
# Name: Name, dtype: int64

# %%
comp_tagid_merged.to_csv("competition_tagid.csv",index=False)

# %%
datasettags = pd.read_csv("DatasetTags.csv")
datasettags.shape
# Out:
# (214254, 3)

# %%
datasettags = datasettags[datasettags.TagId.isin(tag_ids)]
datasettags.shape
# Out:
# (18405, 3)

# %%
datasettags.head()
# Out:
#          Id  DatasetId  TagId
# 25   126987         17  11111
# 33    96588         19   7100
# 37       74         21   4202
# 85      295         52   7100
# 104     158         59   4202

# %%
dataset_ids = datasettags.DatasetId.unique()
len(dataset_ids)
# Out:
# 13104

# %%
datasettags.groupby('TagId')['DatasetId'].count()
# Out:
# TagId
# 4202     1079
# 7100     2218
# 11111    3782
# 13207    2152
# 13302    3032
# 14102    4453
# 14201     688
# 14202     845
# 16636     156
# Name: DatasetId, dtype: int64

# %%
datasettags.groupby('DatasetId')['TagId'].count()
# Out:
# DatasetId
# 17         1
# 19         1
# 21         1
# 52         1
# 59         3
#           ..
# 3070077    1
# 3070688    1
# 3070846    1
# 3071498    1
# 3072156    1
# Name: TagId, Length: 13104, dtype: int64

# %%
dataset = pd.read_csv("Datasets.csv")
dataset.shape
# Out:
# (213535, 14)

# %%
dataset = dataset[dataset.Id.isin(dataset_ids)]
dataset.shape
# Out:
# (13104, 14)

# %%
dataset.rename(columns={'OwnerOrganizationId':'OrgId'},inplace=True)

# %%
dataset.OrgId.nunique()
# Out:
# 69

# %%
org = pd.read_csv("Organizations.csv")
org.shape
# Out:
# (681, 5)

# %%
org.rename(columns={'Id':'OrgId'},inplace=True)

# %%
org.OrgId.nunique()
# Out:
# 681

# %%
dataset_org_merged = pd.merge(dataset,org, on = 'OrgId', how = 'left').reset_index(drop=True)
dataset_org_merged.shape
# Out:
# (13104, 18)

# %%
dataset_org_merged.head()
# Out:
#    DatasetId  CreatorUserId  OwnerUserId  OrgId  CurrentDatasetVersionId  \
# 0         21              1          NaN    9.0                   2159.0
# 1        107         690548     690548.0    NaN                    234.0
# 2        458         665419     665419.0    NaN                    971.0
# 3         76         552951          NaN  223.0                    161.0
# 4        101         632903     632903.0    NaN                    224.0
#
#    CurrentDatasourceVersionId  ForumId  Type       CreationDate_x  \
# 0                      2159.0     1015     2  01/20/2016 16:32:33
# 1                       234.0     1423     2  08/19/2016 09:43:45
# 2                       971.0     2062     2  11/27/2016 10:28:49
# 3                       161.0     1372     2  07/16/2016 03:50:21
# 4                       224.0     1417     2  08/18/2016 13:41:05
#
#   LastActivityDate  TotalViews  TotalDownloads  TotalVotes  TotalKernels  \
# ...

# %%
dataset_org_merged.rename(columns={'Id':'DatasetId'},inplace=True)

# %%
dataset_org_merged.Name.unique()
# Out:
# array(['US Department of Health and Human Services', nan,
#        'Centers for Disease Control and Prevention',
#        'UCI Machine Learning', 'Figure Eight', 'Dryad Digital Repository',
#        'figshare', 'National Library of Medicine',
#        'Center for Medicare and Medicaid', 'National Health Service',
#        'US Environmental Protection Agency', 'University of Copenhagen',
#        "McDonald's", 'Flaredown', 'Medicare', '4Quant',
#        'Zalando Research', 'Food and Drug Administration',
#        'University of Pittsburgh',
#        'BioSENSE @ UC Berkeley School of Information', 'World Bank',
#        'Centers for Medicare & Medicaid Services',
#        'Open Sourcing Mental Illness, LTD', 'Visual Computing Lab - NTNU',
#        'Joint Research Centre', 'Stanford University', 'Bengali.AI',
#        'NYC Parks and Recreation', 'Open Food Facts', 'PromptCloud',
#        'AIFirst', 'Google News Lab', 'IHM Stefanini',
# ...

# %%
datasettags.head()
# Out:
#          Id  DatasetId  TagId
# 25   126987         17  11111
# 33    96588         19   7100
# 37       74         21   4202
# 85      295         52   7100
# 104     158         59   4202

# %%
dataset_org_merged_1 = pd.merge(dataset_org_merged,datasettags[['DatasetId','TagId']], on = 'DatasetId', how = 'left').reset_index(drop=True)
dataset_org_merged_1.shape
# Out:
# (18405, 19)

# %%
dataset_org_merged_1.TagId.nunique()
# Out:
# 9

# %%
tag_orgname = comp_tagid_merged[['TagId','Name']]
tag_orgname
# Out:
#     TagId                       Name
# 0   13302             classification
# 1   14102                      image
# 2    4202                 healthcare
# 3   14102                      image
# 4    7100                    biology
# 5   11111                     health
# 6   14102                      image
# 7   14102                      image
# 8   14202  multiclass classification
# 9   16636  multilabel classification
# 10   4202                 healthcare
# 11  14102                      image
# 12  14201      binary classification
# 13   7100                    biology
# 14  13207            computer vision
# 15  14102                      image

# %%
tag_orgname.drop_duplicates(inplace=True,ignore_index=True)
tag_orgname
# Out:
# <ipython-input-195-39e10361c482>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tag_orgname.drop_duplicates(inplace=True,ignore_index=True)
#    TagId                       Name
# 0  13302             classification
# 1  14102                      image
# 2   4202                 healthcare
# 3   7100                    biology
# 4  11111                     health
# 5  14202  multiclass classification
# 6  16636  multilabel classification
# 7  14201      binary classification
# 8  13207            computer vision

# %%
dataset_org_merged_1 = pd.merge(dataset_org_merged_1,tag_orgname, on = 'TagId', how = 'left').reset_index(drop=True)
dataset_org_merged_1.shape
# Out:
# (18405, 20)

# %%
dataset_org_merged_1.to_csv("Dataset_OrgName.csv",index=False)

# %%
dataset_org_merged_1.head()
# Out:
#    DatasetId  CreatorUserId  OwnerUserId  OrgId  CurrentDatasetVersionId  \
# 0         21              1          NaN    9.0                   2159.0
# 1        107         690548     690548.0    NaN                    234.0
# 2        458         665419     665419.0    NaN                    971.0
# 3        458         665419     665419.0    NaN                    971.0
# 4         76         552951          NaN  223.0                    161.0
#
#    CurrentDatasourceVersionId  ForumId  Type       CreationDate_x  \
# 0                      2159.0     1015     2  01/20/2016 16:32:33
# 1                       234.0     1423     2  08/19/2016 09:43:45
# 2                       971.0     2062     2  11/27/2016 10:28:49
# 3                       971.0     2062     2  11/27/2016 10:28:49
# 4                       161.0     1372     2  07/16/2016 03:50:21
#
#   LastActivityDate  TotalViews  TotalDownloads  TotalVotes  TotalKernels  \
# ...

# %%
dataset_org_merged_1.rename(columns={'Name_x':'Owner Organisation','Name_y':'Parent Tag Name'},inplace=True)

# %%
comp_names
# Out:
# {10418: 'Human Protein Atlas Image Classification',
#  11433: 'XRay Lung Segmentation',
#  14502: 'ECE4250 Project : Spring 2019',
#  20604: 'OSIC Pulmonary Fibrosis Progression',
#  22990: 'HuBMAP - Hacking the Kidney',
#  23823: 'Human Protein Atlas - Single Cell Classification',
#  27177: 'D012554 - 2021',
#  27290: 'BMI707/EPI290 Assignment 2 Q5',
#  29653: 'RSNA-MICCAI Brain Tumor Radiogenomic Classification',
#  34547: 'HuBMAP + HPA - Hacking the Human Body'}

# %%
pwd
# Out:
# '/Users/prataprc94/Desktop/Sem4_Spring2023_Courses/ENGR-E583 InfoVis(Visual Analytics)/Project/Code'

# %%
df_submission = pd.read_csv("data_2/submission_10competitions.csv",index_col=None)
df_submission.drop('index',axis=1,inplace=True)
df_submission.shape
# Out:
# (258837, 12)

# %%
df_submission.head()
# Out:
#         Id  SubmittedUserId   TeamId  SourceKernelVersionId SubmissionDate  \
# 0  8705562         906325.0  2184008              6466538.0     10/14/2018
# 1  8701003         906325.0  2184008              6461939.0     10/14/2018
# 2  8785774         906325.0  2184008              6687978.0     10/22/2018
# 3  8827329         906325.0  2184008              6780709.0     10/26/2018
# 4  8837430         906325.0  2184008              6816029.0     10/27/2018
#
#     ScoreDate  IsAfterDeadline  PublicScoreLeaderboardDisplay  \
# 0  12/05/2018            False                        0.13220
# 1  12/05/2018            False                        0.26235
# 2  12/05/2018            False                        0.34494
# 3  12/05/2018            False                        0.43485
# 4  12/05/2018            False                        0.45704
#
#    PublicScoreFullPrecision  PrivateScoreLeaderboardDisplay  \
# 0                  0.132200                         0.12827
# ...

# %%
df_submission['Competition_Name'] = df_submission['CompetitionId'].map(comp_names)

# %%
df_submission.head()
# Out:
#         Id  SubmittedUserId   TeamId  SourceKernelVersionId SubmissionDate  \
# 0  8705562         906325.0  2184008              6466538.0     10/14/2018
# 1  8701003         906325.0  2184008              6461939.0     10/14/2018
# 2  8785774         906325.0  2184008              6687978.0     10/22/2018
# 3  8827329         906325.0  2184008              6780709.0     10/26/2018
# 4  8837430         906325.0  2184008              6816029.0     10/27/2018
#
#     ScoreDate  IsAfterDeadline  PublicScoreLeaderboardDisplay  \
# 0  12/05/2018            False                        0.13220
# 1  12/05/2018            False                        0.26235
# 2  12/05/2018            False                        0.34494
# 3  12/05/2018            False                        0.43485
# 4  12/05/2018            False                        0.45704
#
#    PublicScoreFullPrecision  PrivateScoreLeaderboardDisplay  \
# 0                  0.132200                         0.12827
# ...

# %%
df_competitions = pd.read_csv("data_2/2_comp_filtered.csv")
df_competitions.head()
# Out:
#       Id                                      Slug  \
# 0  10418  human-protein-atlas-image-classification
# 1  11433                    xray-lung-segmentation
# 2  14502              cornell-ece4250-finalproject
# 3  20604       osic-pulmonary-fibrosis-progression
# 4  22990                hubmap-kidney-segmentation
#
#                                       Title  \
# 0  Human Protein Atlas Image Classification
# 1                    XRay Lung Segmentation
# 2             ECE4250 Project : Spring 2019
# 3       OSIC Pulmonary Fibrosis Progression
# 4               HuBMAP - Hacking the Kidney
#
#                                             Subtitle HostSegmentTitle  \
# 0  Classify subcellular protein patterns in human...         Featured
# 1  Сегментация легких на рентгенологических изобр...        Community
# 2                Automatic segmentation of brain MRI        Community
# 3                      Predict lung function decline         Featured
# ...

# %%
eval_names = dict(zip(df_competitions['Id'],df_competitions['EvaluationAlgorithmAbbreviation']))
eval_names
# Out:
# {10418: 'FScoreMacro',
#  11433: 'Dice',
#  14502: 'Dice',
#  20604: 'LaplaceLogLikelihood',
#  22990: 'Dice',
#  23823: 'OpenImagesObjDetectionSegmentationAP',
#  27177: 'AUC',
#  27290: 'CategorizationAccuracy',
#  29653: 'AUC',
#  34547: 'Dice'}

# %%
df_submission['Evaluation_Algorithm_Name'] = df_submission['CompetitionId'].map(eval_names)

# %%
df_submission.head()
# Out:
#         Id  SubmittedUserId   TeamId  SourceKernelVersionId SubmissionDate  \
# 0  8705562         906325.0  2184008              6466538.0     10/14/2018
# 1  8701003         906325.0  2184008              6461939.0     10/14/2018
# 2  8785774         906325.0  2184008              6687978.0     10/22/2018
# 3  8827329         906325.0  2184008              6780709.0     10/26/2018
# 4  8837430         906325.0  2184008              6816029.0     10/27/2018
#
#     ScoreDate  IsAfterDeadline  PublicScoreLeaderboardDisplay  \
# 0  12/05/2018            False                        0.13220
# 1  12/05/2018            False                        0.26235
# 2  12/05/2018            False                        0.34494
# 3  12/05/2018            False                        0.43485
# 4  12/05/2018            False                        0.45704
#
#    PublicScoreFullPrecision  PrivateScoreLeaderboardDisplay  \
# 0                  0.132200                         0.12827
# ...

# %%
df_submission.to_csv("final_data/submission_10competitions.csv",index=False)

# %%
df_topuser10comp = pd.read_csv("data_2/top_users_top10teams_allcomp.csv")
df_topuser10comp.head()
# Out:
#    UserId       UserName     DisplayName RegisterDate  PerformanceTier  \
# 0   54836       titericz            Giba   08/23/2012                4
# 1   71783  sergeifironov  Sergei Fironov   11/30/2012                4
# 2  111220     kevinhwang     Kevin Hwang   06/20/2013                3
# 3  113660       hengck23        ‎‎‎‎‎‎‎‎   07/11/2013                4
# 4  207760  igorkrashenyi  Igor Krashenyi   06/12/2014                3
#
#    Team_Id  CompetitionId  TeamLeaderId  PublicLeaderboardRank    tier_name  \
# 0  6145769          22990        698363                    1.0  grandmaster
# 1  2274438          10418        837103                    4.0  grandmaster
# 2  2261835          10418        417337                    3.0       master
# 3  8806840          34547        113660                    7.0  grandmaster
# 4  5843694          22990        207760                   10.0       master
#
#    isLeader
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True

# %%
df_topuser10comp['Competition_Name'] = df_topuser10comp['CompetitionId'].map(comp_names)

# %%
df_topuser10comp.head()
# Out:
#    UserId       UserName     DisplayName RegisterDate  PerformanceTier  \
# 0   54836       titericz            Giba   08/23/2012                4
# 1   71783  sergeifironov  Sergei Fironov   11/30/2012                4
# 2  111220     kevinhwang     Kevin Hwang   06/20/2013                3
# 3  113660       hengck23        ‎‎‎‎‎‎‎‎   07/11/2013                4
# 4  207760  igorkrashenyi  Igor Krashenyi   06/12/2014                3
#
#    Team_Id  CompetitionId  TeamLeaderId  PublicLeaderboardRank    tier_name  \
# 0  6145769          22990        698363                    1.0  grandmaster
# 1  2274438          10418        837103                    4.0  grandmaster
# 2  2261835          10418        417337                    3.0       master
# 3  8806840          34547        113660                    7.0  grandmaster
# 4  5843694          22990        207760                   10.0       master
#
#    isLeader                          Competition_Name
# ...

# %%
df_topuser10comp.to_csv("final_data/top_users_top10teams_allcomp.csv",index=False)

# %%
df_allusers = pd.read_csv("data_2/all_users_top10comps_.csv")
df_allusers.head()
# Out:
#    UserId      UserName        DisplayName RegisterDate  PerformanceTier  \
# 0     368  antgoldbloom  Anthony Goldbloom   01/20/2010                2
# 1     368  antgoldbloom  Anthony Goldbloom   01/20/2010                2
# 2     368  antgoldbloom  Anthony Goldbloom   01/20/2010                2
# 3     421       dremovd     Dmitry Dryomov   02/28/2010                3
# 4     602      wahalulu      Marck Vaisman   04/28/2010                0
#
#    Team_Id  CompetitionId  TeamLeaderId  PublicLeaderboardRank     tier_name  \
# 0  3304624          10418           368                    NaN  intermediate
# 1  5556128          20604           368                    NaN  intermediate
# 2  6289988          23823           368                    NaN  intermediate
# 3  5404773          20604           421                  858.0        expert
# 4  7093405          29653           602                    NaN        novice
#
#    isLeader
# 0      True
# 1      True
# 2      True
# ...

# %%
df_allusers['Competition_Name'] = df_allusers['CompetitionId'].map(comp_names)
df_allusers.head()
# Out:
#    UserId      UserName        DisplayName RegisterDate  PerformanceTier  \
# 0     368  antgoldbloom  Anthony Goldbloom   01/20/2010                2
# 1     368  antgoldbloom  Anthony Goldbloom   01/20/2010                2
# 2     368  antgoldbloom  Anthony Goldbloom   01/20/2010                2
# 3     421       dremovd     Dmitry Dryomov   02/28/2010                3
# 4     602      wahalulu      Marck Vaisman   04/28/2010                0
#
#    Team_Id  CompetitionId  TeamLeaderId  PublicLeaderboardRank     tier_name  \
# 0  3304624          10418           368                    NaN  intermediate
# 1  5556128          20604           368                    NaN  intermediate
# 2  6289988          23823           368                    NaN  intermediate
# 3  5404773          20604           421                  858.0        expert
# 4  7093405          29653           602                    NaN        novice
#
#    isLeader                                   Competition_Name
# ...

# %%
df_allusers.to_csv("final_data/all_users_top10comps_.csv",index=False)

# %%
df_comptagid = pd.read_csv("data_2/competition_tagid.csv")
df_comptagid.head()
# Out:
#     Id  CompetitionId  TagId  ParentTagId            Name            Slug  \
# 0  429          10418  13302        16673  classification  classification
# 1  428          10418  14102        14100           image      image-data
# 2  694          20604   4202        11111      healthcare      healthcare
# 3  693          20604  14102        14100           image      image-data
# 4  748          22990   7100         7000         biology         biology
#
#                                             FullPath  \
# 0                              task > classification
# 1                                  data type > image
# 2  subject > health and fitness > health > health...
# 3                                  data type > image
# 4               subject > earth and nature > biology
#
#                                          Description  DatasetCount  \
# 0                                                NaN          3223
# ...

# %%
df_comptagid['Competition_Name'] = df_comptagid['CompetitionId'].map(comp_names)
df_comptagid.head()
# Out:
#     Id  CompetitionId  TagId  ParentTagId            Name            Slug  \
# 0  429          10418  13302        16673  classification  classification
# 1  428          10418  14102        14100           image      image-data
# 2  694          20604   4202        11111      healthcare      healthcare
# 3  693          20604  14102        14100           image      image-data
# 4  748          22990   7100         7000         biology         biology
#
#                                             FullPath  \
# 0                              task > classification
# 1                                  data type > image
# 2  subject > health and fitness > health > health...
# 3                                  data type > image
# 4               subject > earth and nature > biology
#
#                                          Description  DatasetCount  \
# 0                                                NaN          3223
# ...

# %%
df_comptagid.to_csv("final_data/competition_tagid.csv",index=False)

# %%
df_dataorg = pd.read_csv("data_2/Dataset_OrgName.csv")
df_dataorg.head()
# Out:
#    DatasetId  CreatorUserId  OwnerUserId  OrgId  CurrentDatasetVersionId  \
# 0         21              1          NaN    9.0                   2159.0
# 1        107         690548     690548.0    NaN                    234.0
# 2        458         665419     665419.0    NaN                    971.0
# 3        458         665419     665419.0    NaN                    971.0
# 4         76         552951          NaN  223.0                    161.0
#
#    CurrentDatasourceVersionId  ForumId  Type       CreationDate_x  \
# 0                      2159.0     1015     2  01/20/2016 16:32:33
# 1                       234.0     1423     2  08/19/2016 09:43:45
# 2                       971.0     2062     2  11/27/2016 10:28:49
# 3                       971.0     2062     2  11/27/2016 10:28:49
# 4                       161.0     1372     2  07/16/2016 03:50:21
#
#   LastActivityDate  TotalViews  TotalDownloads  TotalVotes  TotalKernels  \
# ...

# %%
df_dataorg.TagId.nunique()
# Out:
# 9

# %%
tagids = df_dataorg.TagId.unique()
tagids
# Out:
# array([ 4202,  7100, 11111, 14102, 14202, 13302, 13207, 14201, 16636])

# %%
df_dataorg.groupby('TagId')['DatasetId'].count()
# Out:
# TagId
# 4202     1079
# 7100     2218
# 11111    3782
# 13207    2152
# 13302    3032
# 14102    4453
# 14201     688
# 14202     845
# 16636     156
# Name: DatasetId, dtype: int64

# %%
df_comptagall = pd.read_csv("CompetitionTags.csv")
df_comptagall.head()
# Out:
#     Id  CompetitionId  TagId
# 0  126           3486  14102
# 1  336           3526  12116
# 2  335           3526  14101
# 3  334           3526  14104
# 4  362           3706   2606

# %%
df_comptagall.groupby('TagId')['CompetitionId'].count()
# Out:
# TagId
# 1219     6
# 2107     4
# 2206     1
# 2303     3
# 2400     1
#         ..
# 16575    8
# 16609    1
# 16627    1
# 16636    3
# 16686    1
# Name: CompetitionId, Length: 107, dtype: int64

# %%
df_comptagall_filt = df_comptagall[df_comptagall.TagId.isin(tagids)]
df_comptagall_filt.shape
# Out:
# (237, 3)

# %%
df_comptagall_filt.groupby('TagId')['CompetitionId'].count()
# Out:
# TagId
# 4202       9
# 7100      10
# 11111      4
# 13207     14
# 13302      5
# 14102    108
# 14201     39
# 14202     45
# 16636      3
# Name: CompetitionId, dtype: int64

# %%
df_comptagall_filt
# Out:
#        Id  CompetitionId  TagId
# 0     126           3486  14102
# 7     322           3810  14202
# 12    301           3936  14202
# 13    128           3947  14102
# 19    287           3949  14201
# ..    ...            ...    ...
# 749  4742          40277  11111
# 761  7206          44630  14201
# 766  7211          44631  14201
# 769  7603          44632  14201
# 777  8546          45892  14201
#
# [237 rows x 3 columns]

# %%
comp_tag_map = dict(zip(df_comptagall_filt['TagId'],df_comptagall_filt['CompetitionId']))
comp_tag_map
# Out:
# {14102: 37333,
#  14202: 36414,
#  14201: 45892,
#  4202: 29653,
#  7100: 34547,
#  13207: 37333,
#  13302: 37333,
#  11111: 40277,
#  16636: 26680}
